# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [19]</a>'.</span>

# %%
# add default values for parameters here

# %%
# Parameters
product = "./5. Quantum simulation/5.6. Building 1D Rydberg Crystals.ipynb"

# %% [markdown]
# # Building 1D Rydberg Crystals

# %% [markdown]
# The following notebook shows a study of many-body dynamics on a 1D system. It is based on [1707.04344](https://arxiv.org/abs/1707.04344). The authors of that paper studied the preparation of symmetry-breaking states in antiferromagnetic Ising chains, by tuning the interaction and driving parameters accross the phase diagram. In this notebook, we reproduce some results of this paper. Since this is a particular experiment not based on certified devices, we will use the `MockDevice` class to allow for a wide range of configuration settings.

# %%
import numpy as np
import matplotlib.pyplot as plt
import qutip

from pulser import Pulse, Sequence, Register
from pulser_simulation import QutipEmulator
from pulser.waveforms import CompositeWaveform, RampWaveform, ConstantWaveform
from pulser.devices import MockDevice

# %% [markdown]
# ## 1. Rydberg Blockade at Resonant Driving

# %% [markdown]
# We first consider clusters of $1, 2$ and $3$ atoms under resonant ($\delta = 0$) driving. If all the atoms are placed within each other's blockade volume, only one excitation per group will be possible at a time. The Rabi frequency will be enhanced by $\sqrt{N}$

# %%
def occupation(reg, j):
    r = qutip.basis(2, 0)
    N = len(reg.qubits)
    prod = [qutip.qeye(2) for _ in range(N)]
    prod[j] = r * r.dag()
    return qutip.tensor(prod)

# %% [markdown]
# Given a value of the maximum Rabi Frequency applied to the atoms, we can calculate the corresponding blockade radius using the `rydberg_blockade_radius()` method from `MockDevice`. We use this to arrange clusters of atoms which will experience this blockade effect:

# %%
Omega_max = 2 * 2 * np.pi
R_blockade = MockDevice.rydberg_blockade_radius(Omega_max)
print(f"Blockade Radius is: {R_blockade}µm.")
groups = 3


def blockade_cluster(N):
    atom_coords = [
        ((R_blockade / N) * x + 40 * group, 0)
        for group in range(groups)
        for x in range(1, N + 1)
    ]
    reg = Register.from_coordinates(atom_coords, prefix="q")
    reg.draw(
        blockade_radius=R_blockade, draw_half_radius=True, draw_graph=False
    )

    resonant_pulse = Pulse.ConstantPulse(1500, Omega_max, 0.0, 0.0)

    seq = Sequence(reg, MockDevice)
    seq.declare_channel("ising", "rydberg_global")
    seq.add(resonant_pulse, "ising")

    simul = QutipEmulator.from_sequence(seq, sampling_rate=0.2)

    obs = [
        sum(occupation(reg, j) for j in range(i, i + N))
        for i in range(0, groups * N, N)
    ]

    res = simul.run(progress_bar=True, method="bdf")
    return res.expect(obs)
# Out:
# Blockade Radius is: 8.692279598222772µm.

# %% [markdown]
# Next we run `blockade_cluster(N)`, which runs the simulation, for clusters of sizes $N \in \{1,2,3\}$:

# %%
data = [blockade_cluster(N) for N in [1, 2, 3]]
# Out:
# 10.0%. Run time:   0.02s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.03s. Est. time left: 00:00:00:00
# 30.0%. Run time:   0.05s. Est. time left: 00:00:00:00
# 40.0%. Run time:   0.06s. Est. time left: 00:00:00:00
# 50.0%. Run time:   0.09s. Est. time left: 00:00:00:00
# 60.0%. Run time:   0.10s. Est. time left: 00:00:00:00
# 70.0%. Run time:   0.15s. Est. time left: 00:00:00:00
# 80.0%. Run time:   0.19s. Est. time left: 00:00:00:00
# 90.0%. Run time:   0.22s. Est. time left: 00:00:00:00
# Total run time:   0.25s
# 10.0%. Run time:   0.03s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.07s. Est. time left: 00:00:00:00
# 30.0%. Run time:   0.12s. Est. time left: 00:00:00:00
# 40.0%. Run time:   0.18s. Est. time left: 00:00:00:00
# 50.0%. Run time:   0.24s. Est. time left: 00:00:00:00
# 60.0%. Run time:   0.33s. Est. time left: 00:00:00:00
# 70.0%. Run time:   0.47s. Est. time left: 00:00:00:00
# 80.0%. Run time:   0.58s. Est. time left: 00:00:00:00
# 90.0%. Run time:   0.73s. Est. time left: 00:00:00:00
# Total run time:   0.86s
# 10.0%. Run time:   2.16s. Est. time left: 00:00:00:19
# 20.0%. Run time:   4.59s. Est. time left: 00:00:00:18
# 30.0%. Run time:   6.73s. Est. time left: 00:00:00:15
# 40.0%. Run time:   8.75s. Est. time left: 00:00:00:13
# 50.0%. Run time:  10.58s. Est. time left: 00:00:00:10
# 60.0%. Run time:  12.56s. Est. time left: 00:00:00:08
# 70.0%. Run time:  14.59s. Est. time left: 00:00:00:06
# 80.0%. Run time:  17.26s. Est. time left: 00:00:00:04
# 90.0%. Run time:  19.44s. Est. time left: 00:00:00:02
# Total run time:  21.41s

# %% [markdown]
# We now plot the probability that a Rydberg state withing the cluster is occupied (by summing the expectation values of the $|r\rangle\langle r|_i$ operators for each cluster) as it evolves in time, revealing the Rabi frequency of each configuration:

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 3))
for N, expectation in enumerate(data):
    ax[N].set_xlabel(r"Time ($µs$)", fontsize=10)
    ax[N].set_ylabel(r"Probability of $|r\rangle$", fontsize=10)
    ax[N].set_title(f"Atoms per cluster N = {N+1}", fontsize=12)
    avg = sum(expectation) / groups
    ax[N].plot(np.arange(len(avg)) / 1000, avg)

# %% [markdown]
# Only one excitation will be shared between the atoms on each cluster. Notice how the Rabi frequency increases by a factor of $\sqrt{N}$

# %% [markdown]
# ## 2. Ordered Crystalline phases

# %% [markdown]
# The pulse sequence that we will prepare is based on the following parameters:

# %%
# Parameters in rad/µs and ns
delta_0 = -6 * 2 * np.pi
delta_f = 10 * 2 * np.pi
Omega_max = 2 * 2 * np.pi
t_rise = 500
t_stop = 4500

# %% [markdown]
# We calculate the blockade radius from the maximal applied Rabi frequency:

# %%
R_blockade = MockDevice.rydberg_blockade_radius(Omega_max)
a = 7.0

reg = Register.rectangle(1, 11, spacing=a, prefix="q")
print(f"Blockade Radius is: {R_blockade}µm.")
reg.draw(blockade_radius=R_blockade, draw_half_radius=True)
# Out:
# Blockade Radius is: 8.692279598222772µm.

# %% [markdown]
# Create the pulses using Pulser objects:

# %%
hold = ConstantWaveform(t_rise, delta_0)
excite = RampWaveform(t_stop - t_rise, delta_0, delta_f)
sweep = Pulse.ConstantAmplitude(
    Omega_max, CompositeWaveform(hold, excite), 0.0
)

# %%
seq = Sequence(reg, MockDevice)
seq.declare_channel("ising", "rydberg_global")

seq.add(sweep, "ising")

seq.draw()

# %% [markdown]
# The pulse sequence we just created corresponds a path in the Phase space of the ground state, which we represent schematically with the following function:

# %%
def phase_diagram(seq):
    ratio = []
    for x in seq._schedule["ising"]:
        if isinstance(x.type, Pulse):
            ratio += list(x.type.detuning.samples / Omega_max)

    fig, ax = plt.subplots()
    ax.grid(True, which="both")

    ax.set_ylabel(r"Interaction Range $R_b/a$", fontsize=14)
    ax.set_xlabel(r"Detuning $\delta/\Omega$", fontsize=14)
    ax.set_xlim(-4, 6)
    ax.set_ylim(0, 3.2)
    ax.axhline(y=0, color="k")
    ax.axvline(x=0, color="k")

    y = np.arange(0.0, 5, 0.01)
    x = 2 * (0.6 + 8 * (y - 1.2) ** 2)
    ax.fill_between(x, y, alpha=0.4)

    y = np.arange(0.0, 5, 0.01)
    x = 2 * (0.8 + 50 * (y - 2.45) ** 2)
    ax.fill_between(x, y, alpha=0.4)

    y = np.arange(0.0, 5, 0.01)
    x = 2 * (1.0 + 170 * (y - 3.06) ** 2)
    ax.fill_between(x, y, alpha=0.4)

    ax.plot(np.array(ratio), np.full(len(ratio), R_blockade / a), "red", lw=2)
    plt.show()

# %%
phase_diagram(seq)

# %% [markdown]
# ### 2.1 Simulation

# %% [markdown]
# We run our simulation, for a list of observables corresponding to $|r\rangle \langle r|_j$ for each atom in the register:

# %%
simul = QutipEmulator.from_sequence(seq, sampling_rate=0.1)

occup_list = [occupation(reg, j) for j in range(len(reg.qubits))]

res = simul.run(progress_bar=True)
occupations = res.expect(occup_list)
# Out:
# 10.0%. Run time:   0.96s. Est. time left: 00:00:00:08
# 20.0%. Run time:   1.94s. Est. time left: 00:00:00:07
# 30.0%. Run time:   3.36s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.70s. Est. time left: 00:00:00:07
# 50.0%. Run time:   5.81s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.61s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.45s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.67s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.92s. Est. time left: 00:00:00:01
# Total run time:  11.13s

# %% [markdown]
# The following function plots the evolution of the expectation values with respect to time:

# %%
def plot_evolution(results):
    plt.figure(figsize=(10, 5))
    plt.xlabel("Time (µs)", fontsize=14)
    plt.ylabel("Rydberg Occupation Probabilty", fontsize=14)
    for expv in results:
        plt.plot(np.arange(len(expv)) / 1000, expv)

    plt.show()

# %%
plot_evolution(occupations)

# %% [markdown]
# We finally plot the probability of occupation of the Rydberg level with respect to the values of detuning, for each atom in the array:

# %%
def heat_detuning(data, start, end):
    N = len(reg.qubits)
    time_window = []
    x = []
    detunings = simul.samples["Global"]["ground-rydberg"]["det"][
        [int(1000 * t) for t in simul.evaluation_times[:-1]]
    ]

    for t, d in enumerate(detunings):
        if start <= d <= end:
            time_window.append(t)
            x.append(d / (2 * np.pi))

    y = np.arange(1, N + 1)

    X, Y = np.meshgrid(x, y)
    Z = np.array(data)[:, time_window]

    plt.figure(figsize=(14, 3))
    plt.pcolormesh(X, Y, Z, cmap="hot", shading="auto")
    plt.xlabel("Detuning/2π (MHz)", fontsize=14)
    plt.ylabel("Atom in array", fontsize=14)
    plt.yticks(range(1, N + 1), [f"q{i}" for i in range(N)], va="center")
    plt.colorbar(fraction=0.047, pad=0.015)

    plt.show()

# %%
heat_detuning(occupations, delta_0, delta_f)

# %% [markdown]
# ### 2.2 Rydberg Crystals: $Z_3$ Order

# %% [markdown]
# To arrive at a different phase, we reduce the interatomic distance $a$, thus increasing the interaction range between the atoms. This will lead to a $Z_3$ ordered phase:

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
a = 3.5
reg = Register.rectangle(1, 10, spacing=a, prefix="q")

delta_0 = -4 * 2 * np.pi
delta_f = 10 * 2 * np.pi
Omega_max = 2.0 * 2 * np.pi  # btw 1.8-2 * 2pi MHz
t_rise = 600
t_stop = 2500
R_blockade = MockDevice.rydberg_blockade_radius(Omega_max)
reg.draw(blockade_radius=R_blockade, draw_half_radius=True)

#
hold = ConstantWaveform(t_rise, delta_0)
excite = RampWaveform(t_stop - t_rise, delta_0, delta_f)
sweep = Pulse.ConstantAmplitude(
    Omega_max, CompositeWaveform(hold, excite), 0.0
)
#
seq = Sequence(reg, MockDevice)
seq.declare_channel("ising", "rydberg_global")
seq.add(sweep, "ising")

phase_diagram(seq)

simul = QutipEmulator.from_sequence(seq, sampling_rate=0.1)

occup_list = [occupation(reg, j) for j in range(simul._size)]

res = simul.run(progress_bar=True, method="bdf")

occupations = res.expect(occup_list)

plot_evolution(occupations)
heat_detuning(occupations, delta_0, delta_f)
# Out:
# 10.0%. Run time:   3.55s. Est. time left: 00:00:00:31
# 20.0%. Run time:   6.97s. Est. time left: 00:00:00:27
# 30.0%. Run time:   9.92s. Est. time left: 00:00:00:23
# 40.0%. Run time:  12.96s. Est. time left: 00:00:00:19
# 50.0%. Run time:  15.74s. Est. time left: 00:00:00:15
# 60.0%. Run time:  18.08s. Est. time left: 00:00:00:12
# 70.0%. Run time:  20.38s. Est. time left: 00:00:00:08
# 80.0%. Run time:  22.48s. Est. time left: 00:00:00:05
# /home/mourad/dev/pasqal/backend/pulser-ovh-tutorials/venv/lib/python3.11/site-packages/scipy/integrate/_ode.py:1011: UserWarning: zvode: Excess work done on this call. (Perhaps wrong MF.)
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[19], line 29
#      25 simul = QutipEmulator.from_sequence(seq, sampling_rate=0.1)
#      27 occup_list = [occupation(reg, j) for j in range(simul._size)]
# ---> 29 res = simul.run(progress_bar=True, method="bdf")
#      31 occupations = res.expect(occup_list)
#      33 plot_evolution(occupations)
#
# File ~/dev/pasqal/backend/pulser-ovh-tutorials/venv/lib/python3.11/site-packages/pulser_simulation/simulation.py:986, in QutipEmulator.run(self, progress_bar, **options)
#     981 if set(self.config.noise).issubset(
#     982     {"dephasing", "SPAM", "depolarizing", "eff_noise"}
#     983 ):
#     984     # If there is "SPAM", the preparation errors must be zero
#     985     if "SPAM" not in self.config.noise or self.config.eta == 0:
# --> 986         return _run_solver()
#     988     else:
#     989         # Stores the different initial configurations and frequency
#     990         initial_configs = Counter(
#     991             "".join(
#     992                 (
#    (...)
#     999             for _ in range(self.config.runs)
#    1000         ).most_common()
#
# File ~/dev/pasqal/backend/pulser-ovh-tutorials/venv/lib/python3.11/site-packages/pulser_simulation/simulation.py:955, in QutipEmulator.run.<locals>._run_solver()
#     946     result = qutip.mesolve(
#     947         self._hamiltonian,
#     948         self.initial_state,
#    (...)
#     952         options=solv_ops,
#     953     )
#     954 else:
# --> 955     result = qutip.sesolve(
#     956         self._hamiltonian,
#     957         self.initial_state,
#     958         self._eval_times_array,
#     959         progress_bar=p_bar,
#     960         options=solv_ops,
#     961     )
#     962 results = [
#     963     QutipResult(
#     964         tuple(self._qdict),
#    (...)
#     969     for state in result.states
#     970 ]
#     971 return CoherentResults(
#     972     results,
#     973     self._size,
#    (...)
#     977     meas_errors,
#     978 )
#
# File ~/dev/pasqal/backend/pulser-ovh-tutorials/venv/lib/python3.11/site-packages/qutip/sesolve.py:136, in sesolve(H, psi0, tlist, e_ops, args, options, progress_bar, _safe_mode)
#     133     v = psi0.full().ravel('F')
#     134     func(0., v, *ode_args) + v
# --> 136 res = _generic_ode_solve(func, ode_args, psi0, tlist, e_ops, options,
#     137                          progress_bar, dims=psi0.dims)
#     138 if e_ops_dict:
#     139     res.expect = {e: res.expect[n]
#     140                   for n, e in enumerate(e_ops_dict.keys())}
#
# File ~/dev/pasqal/backend/pulser-ovh-tutorials/venv/lib/python3.11/site-packages/qutip/sesolve.py:329, in _generic_ode_solve(func, ode_args, psi0, tlist, e_ops, opt, progress_bar, dims)
#     327 progress_bar.update(t_idx)
#     328 if not r.successful():
# --> 329     raise Exception("ODE integration error: Try to increase "
#     330                     "the allowed number of substeps by increasing "
#     331                     "the nsteps parameter in the Options class.")
#     332 # get the current state / oper data if needed
#     333 if opt.store_states or opt.normalize_output \
#     334    or n_expt_op > 0 or expt_callback:
#
# Exception: ODE integration error: Try to increase the allowed number of substeps by increasing the nsteps parameter in the Options class.

# %% [markdown]
# ### 2.3 Rydberg Crystals: $Z_4$ Order

# %% [markdown]
# Decreasing even more the interatomic distance leads to a $Z_4$ order. The magnitude of the Rydberg interaction with respect to that of the applied pulses means our solver has to control terms with a wider range, thus leading to longer simulation times:

# %%
a = 2.8
reg = Register.rectangle(1, 9, spacing=a, prefix="q")

# Parameters in rad/µs and ns

delta_0 = -4 * 2 * np.pi
delta_f = 10 * 2 * np.pi
Omega_max = 2.0 * 2 * np.pi  # btw 1.8-2 2pi*MHz
t_rise = 600
t_stop = 2500
R_blockade = MockDevice.rydberg_blockade_radius(Omega_max)
reg.draw(blockade_radius=R_blockade, draw_half_radius=True)

#
hold = ConstantWaveform(t_rise, delta_0)
excite = RampWaveform(t_stop - t_rise, delta_0, delta_f)
sweep = Pulse.ConstantAmplitude(
    Omega_max, CompositeWaveform(hold, excite), 0.0
)

#
seq = Sequence(reg, MockDevice)
seq.declare_channel("ising", "rydberg_global")
seq.add(sweep, "ising")

phase_diagram(seq)

simul = QutipEmulator.from_sequence(seq, sampling_rate=0.4)

occup_list = [occupation(reg, j) for j in range(len(reg.qubits))]

#
res = simul.run(progress_bar=True, method="bdf")
occupations = res.expect(occup_list)

plot_evolution(occupations)
heat_detuning(occupations, delta_0, delta_f)
